# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas6028/x-coach/blob/main/run_videomae_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 將影片解壓縮到 Colab 本機端

# %%
# 建立一個本機資料夾用來放影片
# !mkdir -p /content/local_videos

# 建立資料夾用來放embeddings
# !mkdir -p /content/drive/MyDrive/x-coach/data/videomae_feature_extraction/train
# !mkdir -p /content/drive/MyDrive/x-coach/data/videomae_feature_extraction/val
# !mkdir -p /content/drive/MyDrive/x-coach/data/videomae_feature_extraction/test

# 將 Google Drive 上的 zip 檔解壓縮到 Colab 本機端 (-q 代表安靜模式，避免洗短畫面)
# !unzip -q /content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/videos.zip -d /content/local_videos

# %% [markdown]
# ### 2. 安裝必要的套件

# %%
# !pip install transformers accelerate timm

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %% [markdown]
# 提取 Train（訓練集）特徵

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_feature_extraction.py \
  --video-root "/content/local_videos" \
  --video-ids "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --output-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction/train" \
  --num-clips 4 \
  --device cuda
# Out:
# Loading VideoMAE model `MCG-NJU/videomae-base-finetuned-kinetics` on cuda...
# ...
# preprocessor_config.json: 100% 271/271 [00:00<00:00, 1.66MB/s]
# config.json: 22.9kB [00:00, 38.2MB/s]
# model.safetensors: 100% 346M/346M [00:02<00:00, 128MB/s]
# Loading weights: 100% 182/182 [00:00<00:00, 1066.38it/s, Materializing param=encoder.layer.11.output.dense.weight]
# VideoMAEModel LOAD REPORT from: MCG-NJU/videomae-base-finetuned-kinetics
# Key               | Status     |  |
# ------------------+------------+--+-
# classifier.bias   | UNEXPECTED |  |
# fc_norm.weight    | UNEXPECTED |  |
# classifier.weight | UNEXPECTED |  |
# fc_norm.bias      | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Processing 1136 videos...
# [1] Skipping 46777_1, already exists.
# [2] Skipping 49897_1, already exists.
# [3] Skipping 47525_3, already exists.
# [4] Skipping 48514_2, already exists.
# ...

# %% [markdown]
# 提取 Validation（驗證集）特徵

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_feature_extraction.py \
  --video-root "/content/local_videos" \
  --video-ids "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --output-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction/val" \
  --num-clips 4 \
  --device cuda
# Out:
# Loading VideoMAE model `MCG-NJU/videomae-base-finetuned-kinetics` on cuda...
# ...
# Loading weights: 100% 182/182 [00:00<00:00, 1259.91it/s, Materializing param=encoder.layer.11.output.dense.weight]
# VideoMAEModel LOAD REPORT from: MCG-NJU/videomae-base-finetuned-kinetics
# Key               | Status     |  |
# ------------------+------------+--+-
# fc_norm.weight    | UNEXPECTED |  |
# fc_norm.bias      | UNEXPECTED |  |
# classifier.bias   | UNEXPECTED |  |
# classifier.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Processing 243 videos...
# [1] Extracting 49807_1 from 49807_1.mp4...
# [2] Extracting 48046_2 from 48046_2.mp4...
# [3] Extracting 48728_4 from 48728_4.mp4...
# [4] Extracting 33599_4 from 33599_4.mp4...
# [5] Extracting 49734_4 from 49734_4.mp4...
# [6] Extracting 37980_2 from 37980_2.mp4...
# [7] Extracting 46570_1 from 46570_1.mp4...
# ...

# %% [markdown]
# 提取 Test（測試集）特徵

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_feature_extraction.py \
  --video-root "/content/local_videos" \
  --video-ids "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --output-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction/test" \
  --num-clips 4 \
  --device cuda
