# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas6028/x-coach/blob/main/notebooks/run_videomae_video_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max_bce-05.pt" \
  --epochs 20
# Out:
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, positives: 812, negatives: 324
# Epoch 01 | loss=0.3558 | train_f1=0.753 val_f1=0.697 val_acc=0.593
# Epoch 02 | loss=0.2708 | train_f1=0.659 val_f1=0.590 val_acc=0.502
# Epoch 03 | loss=0.2447 | train_f1=0.498 val_f1=0.427 val_acc=0.469
# Epoch 04 | loss=0.2431 | train_f1=0.839 val_f1=0.699 val_acc=0.588
# Epoch 05 | loss=0.2335 | train_f1=0.585 val_f1=0.480 val_acc=0.473
# Epoch 06 | loss=0.2116 | train_f1=0.474 val_f1=0.364 val_acc=0.440
# Epoch 07 | loss=0.2073 | train_f1=0.356 val_f1=0.301 val_acc=0.407
# Epoch 08 | loss=0.2061 | train_f1=0.792 val_f1=0.599 val_acc=0.527
# Epoch 09 | loss=0.1833 | train_f1=0.719 val_f1=0.500 val_acc=0.473
# Epoch 10 | loss=0.1717 | train_f1=0.783 val_f1=0.592 val_acc=0.519
# Epoch 11 | loss=0.1698 | train_f1=0.872 val_f1=0.639 val_acc=0.539
# Epoch 12 | loss=0.1541 | train_f1=0.914 val_f1=0.775 val_acc=0.646
# Epoch 13 | loss=0.1688 | train_f1=0.787 val_f1=0.564 val_acc=0.510
# Epoch 14 | loss=0.1436 | train_f1=0.848 val_f1=0.656 val_acc=0.556
# Epoch 15 | loss=0.1368 | train_f1=0.918 val_f1=0.679 val_acc=0.568
# Epoch 16 | loss=0.1254 | train_f1=0.898 val_f1=0.649 val_acc=0.556
# Epoch 17 | loss=0.1249 | train_f1=0.933 val_f1=0.692 val_acc=0.572
# Epoch 18 | loss=0.1249 | train_f1=0.923 val_f1=0.671 val_acc=0.564
# Epoch 19 | loss=0.1082 | train_f1=0.877 val_f1=0.625 val_acc=0.535
# Epoch 20 | loss=0.0948 | train_f1=0.946 val_f1=0.709 val_acc=0.601
# Saved best checkpoint to /content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max_bce-05.pt
# Test metrics | accuracy=0.611 precision=0.736 recall=0.698 f1=0.716
