# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas6028/x-coach/blob/main/notebooks/run_videomae_video_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max.pt" \
  --epochs 20
# Out:
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, positives: 812, negatives: 324
# Epoch 01 | loss=0.5155 | train_f1=0.784 val_f1=0.755 val_acc=0.650
# Epoch 02 | loss=0.3857 | train_f1=0.250 val_f1=0.249 val_acc=0.403
# Epoch 03 | loss=0.3886 | train_f1=0.791 val_f1=0.699 val_acc=0.593
# Epoch 04 | loss=0.3471 | train_f1=0.680 val_f1=0.572 val_acc=0.527
# Epoch 05 | loss=0.3395 | train_f1=0.442 val_f1=0.383 val_acc=0.457
# Epoch 06 | loss=0.3141 | train_f1=0.752 val_f1=0.651 val_acc=0.564
# Epoch 07 | loss=0.3009 | train_f1=0.782 val_f1=0.601 val_acc=0.531
# Epoch 08 | loss=0.2849 | train_f1=0.855 val_f1=0.701 val_acc=0.588
# Epoch 09 | loss=0.3068 | train_f1=0.810 val_f1=0.612 val_acc=0.531
# Epoch 10 | loss=0.2793 | train_f1=0.721 val_f1=0.528 val_acc=0.486
# Epoch 11 | loss=0.2692 | train_f1=0.913 val_f1=0.764 val_acc=0.654
# Epoch 12 | loss=0.2663 | train_f1=0.731 val_f1=0.532 val_acc=0.494
# Epoch 13 | loss=0.2429 | train_f1=0.850 val_f1=0.620 val_acc=0.527
# Epoch 14 | loss=0.2199 | train_f1=0.912 val_f1=0.751 val_acc=0.626
# Epoch 15 | loss=0.1998 | train_f1=0.930 val_f1=0.732 val_acc=0.626
# Epoch 16 | loss=0.1804 | train_f1=0.916 val_f1=0.716 val_acc=0.601
# Epoch 17 | loss=0.1938 | train_f1=0.859 val_f1=0.658 val_acc=0.576
# Epoch 18 | loss=0.1719 | train_f1=0.886 val_f1=0.638 val_acc=0.547
# Epoch 19 | loss=0.1711 | train_f1=0.909 val_f1=0.647 val_acc=0.551
# Epoch 20 | loss=0.1638 | train_f1=0.952 val_f1=0.758 val_acc=0.638
# Saved best checkpoint to /content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max.pt
# Test metrics | accuracy=0.656 precision=0.716 recall=0.849 f1=0.777
