# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas6028/x-coach/blob/main/run_videomae_video_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints" \
  --epochs 10
# Out:
# Warning: 214 videos are missing features: 49565_5, 36809_2, 48539_5, 47591_2, 46376_1, 49868_1, 37083_1, 49956_1, 50033_2, 50331_4 ... (+204 more)
# Training on 1136 train / 243 val / 30 test samples.
# Feature dim: 768, positives: 812, negatives: 324
# Epoch 01 | loss=0.5003 | train_f1=0.841 val_f1=0.769 val_acc=0.642
# Epoch 02 | loss=0.3830 | train_f1=0.843 val_f1=0.764 val_acc=0.642
# Epoch 03 | loss=0.3762 | train_f1=0.817 val_f1=0.694 val_acc=0.572
# Epoch 04 | loss=0.3242 | train_f1=0.784 val_f1=0.656 val_acc=0.556
# Epoch 05 | loss=0.3122 | train_f1=0.859 val_f1=0.712 val_acc=0.597
# Epoch 06 | loss=0.2931 | train_f1=0.842 val_f1=0.725 val_acc=0.613
# Epoch 07 | loss=0.2856 | train_f1=0.765 val_f1=0.630 val_acc=0.560
# Epoch 08 | loss=0.2903 | train_f1=0.910 val_f1=0.768 val_acc=0.642
# Epoch 09 | loss=0.2409 | train_f1=0.903 val_f1=0.756 val_acc=0.646
# Epoch 10 | loss=0.2382 | train_f1=0.876 val_f1=0.681 val_acc=0.580
# Saved best checkpoint to /content/drive/.shortcut-targets-by-id/1fsHeG7uuKZIhLaAL31tvavXXbsdt7znY/x-coach/data/Squat/videomae_classifier.pt
# Test metrics | accuracy=0.600 precision=0.762 recall=0.696 f1=0.727
