# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas6028/x-coach/blob/main/notebooks/run_videomae_video_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max2.pt" \
  --epochs 20
# Out:
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, positives: 812, negatives: 324
# Epoch 01 | loss=0.5855 | train_f1=0.535 val_f1=0.528 val_acc=0.486
# Epoch 02 | loss=0.3963 | train_f1=0.761 val_f1=0.675 val_acc=0.572
# Epoch 03 | loss=0.3555 | train_f1=0.830 val_f1=0.702 val_acc=0.584
# Epoch 04 | loss=0.3372 | train_f1=0.850 val_f1=0.744 val_acc=0.621
# Epoch 05 | loss=0.3199 | train_f1=0.873 val_f1=0.747 val_acc=0.617
# Epoch 06 | loss=0.3081 | train_f1=0.880 val_f1=0.739 val_acc=0.613
# Epoch 07 | loss=0.2965 | train_f1=0.878 val_f1=0.724 val_acc=0.605
# Epoch 08 | loss=0.2879 | train_f1=0.868 val_f1=0.694 val_acc=0.572
# Epoch 09 | loss=0.2670 | train_f1=0.899 val_f1=0.770 val_acc=0.654
# Epoch 10 | loss=0.2646 | train_f1=0.856 val_f1=0.673 val_acc=0.576
# Epoch 11 | loss=0.2465 | train_f1=0.916 val_f1=0.747 val_acc=0.613
# Epoch 12 | loss=0.2554 | train_f1=0.939 val_f1=0.781 val_acc=0.663
# Epoch 13 | loss=0.2115 | train_f1=0.830 val_f1=0.628 val_acc=0.556
# Epoch 14 | loss=0.2060 | train_f1=0.734 val_f1=0.529 val_acc=0.502
# Epoch 15 | loss=0.1965 | train_f1=0.931 val_f1=0.699 val_acc=0.588
# Epoch 16 | loss=0.1735 | train_f1=0.905 val_f1=0.711 val_acc=0.605
# Epoch 17 | loss=0.1670 | train_f1=0.902 val_f1=0.667 val_acc=0.572
# Epoch 18 | loss=0.1935 | train_f1=0.927 val_f1=0.805 val_acc=0.683
# Epoch 19 | loss=0.1709 | train_f1=0.890 val_f1=0.638 val_acc=0.547
# Epoch 20 | loss=0.1375 | train_f1=0.938 val_f1=0.652 val_acc=0.547
# Saved best checkpoint to /content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max2.pt
# Test metrics | accuracy=0.586 precision=0.735 recall=0.645 f1=0.687
