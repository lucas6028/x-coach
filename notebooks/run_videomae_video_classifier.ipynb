# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier.pt" \
  --epochs 20 \
  --lr 3e-4 \
  --hidden-dim 128 \
  --dropout 0.4 \
  --weight-decay 0.01 \
  --early-stopping-patience 5 \
  --seed 42 \
  --threshold-objective balanced_accuracy \
  --label-mode combined \
  --predictions-output "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/predictions/videomae_classifier_seed42_predictions.csv" \
  --summary-output "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/metrics/videomae_classifier_seed42_metrics.json"
# Out:
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, seed: 42
# Class balance | train positives=812 negatives=324 | val positives=165 negatives=78 | test positives=172 negatives=72
# Epoch 01 | loss=0.5223 | train_f1=0.827 val_bal_acc=0.553 val_f1=0.722 val_specificity=0.372 val_threshold=0.655
# Epoch 02 | loss=0.4006 | train_f1=0.675 val_bal_acc=0.563 val_f1=0.768 val_specificity=0.295 val_threshold=0.389
# Epoch 03 | loss=0.3699 | train_f1=0.343 val_bal_acc=0.554 val_f1=0.562 val_specificity=0.654 val_threshold=0.390
# Epoch 04 | loss=0.3608 | train_f1=0.821 val_bal_acc=0.572 val_f1=0.409 val_specificity=0.872 val_threshold=0.707
# Epoch 05 | loss=0.3361 | train_f1=0.868 val_bal_acc=0.548 val_f1=0.635 val_specificity=0.526 val_threshold=0.774
# Epoch 06 | loss=0.3316 | train_f1=0.764 val_bal_acc=0.567 val_f1=0.704 val_specificity=0.449 val_threshold=0.432
# ...

# %% [markdown]
# ### 4. 執行多 seed / 多標籤實驗

# %%
# !python /content/drive/MyDrive/x-coach/src/run_videomae_experiment_grid.py \
  --classifier-script "/content/drive/MyDrive/x-coach/src/videomae_video_classifier.py" \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-root "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier" \
  --label-modes combined,knees_forward,knees_inward \
  --seeds 1,2,3,4,5 \
  --epochs 20 \
  --lr 3e-4 \
  --hidden-dim 128 \
  --dropout 0.4 \
  --weight-decay 0.01 \
  --early-stopping-patience 5 \
  --threshold-objective balanced_accuracy
# Out:
# Running label_mode=combined seed=1
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, seed: 1
# Class balance | train positives=812 negatives=324 | val positives=165 negatives=78 | test positives=172 negatives=72
# Epoch 01 | loss=0.5055 | train_f1=0.392 val_bal_acc=0.592 val_f1=0.512 val_specificity=0.808 val_threshold=0.457 early_stop_wait=0
# Epoch 02 | loss=0.4091 | train_f1=0.549 val_bal_acc=0.584 val_f1=0.682 val_specificity=0.538 val_threshold=0.446 early_stop_wait=0
# Epoch 03 | loss=0.3869 | train_f1=0.701 val_bal_acc=0.556 val_f1=0.721 val_specificity=0.385 val_threshold=0.463 early_stop_wait=1
# Epoch 04 | loss=0.3657 | train_f1=0.849 val_bal_acc=0.557 val_f1=0.751 val_specificity=0.321 val_threshold=0.544 early_stop_wait=2
# Epoch 05 | loss=0.3496 | train_f1=0.786 val_bal_acc=0.579 val_f1=0.667 val_specificity=0.551 val_threshold=0.526 early_stop_wait=3
# ...

# %%
# !python /content/drive/MyDrive/x-coach/src/run_videomae_experiment_grid.py \
    --feature-dir "/content/drive/MyDrive/x-coach/data/Squat/Labeled_Dataset/pose_features" \
    --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
    --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
    --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
    --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
    --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
    --output-root "/content/drive/MyDrive/x-coach/data/Squat/pose_classifier_experiments_normalize" \
    --normalize-features
# Out:
# Running label_mode=combined seed=1
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 654, seed: 1
# Feature normalization: train-set z-score
# Class balance | train positives=812 negatives=324 | val positives=165 negatives=78 | test positives=172 negatives=72
# Epoch 01 | loss=0.3818 | train_f1=0.782 val_bal_acc=0.685 val_f1=0.844 val_specificity=0.449 val_threshold=0.403 early_stop_wait=0
# Epoch 02 | loss=0.3540 | train_f1=0.799 val_bal_acc=0.689 val_f1=0.839 val_specificity=0.474 val_threshold=0.417 early_stop_wait=0
# Epoch 03 | loss=0.3412 | train_f1=0.797 val_bal_acc=0.685 val_f1=0.844 val_specificity=0.449 val_threshold=0.359 early_stop_wait=0
# Epoch 04 | loss=0.3303 | train_f1=0.814 val_bal_acc=0.698 val_f1=0.811 val_specificity=0.577 val_threshold=0.471 early_stop_wait=1
# Epoch 05 | loss=0.3239 | train_f1=0.820 val_bal_acc=0.686 val_f1=0.744 val_specificity=0.692 val_threshold=0.555 early_stop_wait=0
# ...
