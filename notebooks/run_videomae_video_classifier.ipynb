# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas6028/x-coach/blob/main/notebooks/run_videomae_video_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max_bce-05.pt" \
  --epochs 20
# Out:
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, positives: 812, negatives: 324
# Epoch 01 | loss=0.4889 | train_f1=0.835 val_f1=0.775 val_acc=0.654
# Epoch 02 | loss=0.3842 | train_f1=0.841 val_f1=0.751 val_acc=0.621
# Epoch 03 | loss=0.3510 | train_f1=0.409 val_f1=0.330 val_acc=0.416
# Epoch 04 | loss=0.3531 | train_f1=0.518 val_f1=0.451 val_acc=0.469
# Epoch 05 | loss=0.3247 | train_f1=0.839 val_f1=0.683 val_acc=0.580
# Epoch 06 | loss=0.3153 | train_f1=0.827 val_f1=0.667 val_acc=0.568
# Epoch 07 | loss=0.3003 | train_f1=0.756 val_f1=0.594 val_acc=0.527
# Epoch 08 | loss=0.2776 | train_f1=0.581 val_f1=0.466 val_acc=0.481
# Epoch 09 | loss=0.2840 | train_f1=0.873 val_f1=0.712 val_acc=0.597
# Epoch 10 | loss=0.2457 | train_f1=0.868 val_f1=0.683 val_acc=0.576
# Epoch 11 | loss=0.2321 | train_f1=0.885 val_f1=0.677 val_acc=0.572
# Epoch 12 | loss=0.2262 | train_f1=0.703 val_f1=0.457 val_acc=0.453
# Epoch 13 | loss=0.2191 | train_f1=0.820 val_f1=0.612 val_acc=0.535
# Epoch 14 | loss=0.2026 | train_f1=0.794 val_f1=0.585 val_acc=0.527
# Epoch 15 | loss=0.1785 | train_f1=0.912 val_f1=0.658 val_acc=0.564
# Epoch 16 | loss=0.1778 | train_f1=0.897 val_f1=0.675 val_acc=0.580
# Epoch 17 | loss=0.1842 | train_f1=0.923 val_f1=0.698 val_acc=0.597
# Epoch 18 | loss=0.1409 | train_f1=0.964 val_f1=0.790 val_acc=0.675
# Epoch 19 | loss=0.1652 | train_f1=0.955 val_f1=0.712 val_acc=0.601
# Epoch 20 | loss=0.1456 | train_f1=0.929 val_f1=0.667 val_acc=0.564
# Saved best checkpoint to /content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max_bce-05.pt
# Test metrics | accuracy=0.594 precision=0.752 recall=0.634 f1=0.688
