# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas6028/x-coach/blob/main/notebooks/run_videomae_video_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max_prob-055.pt" \
  --epochs 20
# Out:
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, positives: 812, negatives: 324
# Epoch 01 | loss=0.6237 | train_f1=0.651 val_f1=0.567 val_acc=0.486
# Epoch 02 | loss=0.3785 | train_f1=0.754 val_f1=0.643 val_acc=0.547
# Epoch 03 | loss=0.3555 | train_f1=0.840 val_f1=0.698 val_acc=0.576
# Epoch 04 | loss=0.3444 | train_f1=0.829 val_f1=0.690 val_acc=0.593
# Epoch 05 | loss=0.3239 | train_f1=0.354 val_f1=0.304 val_acc=0.416
# Epoch 06 | loss=0.3256 | train_f1=0.848 val_f1=0.741 val_acc=0.630
# Epoch 07 | loss=0.3341 | train_f1=0.868 val_f1=0.713 val_acc=0.597
# Epoch 08 | loss=0.2765 | train_f1=0.708 val_f1=0.523 val_acc=0.498
# Epoch 09 | loss=0.2843 | train_f1=0.523 val_f1=0.407 val_acc=0.461
# Epoch 10 | loss=0.2567 | train_f1=0.898 val_f1=0.754 val_acc=0.638
# Epoch 11 | loss=0.2402 | train_f1=0.920 val_f1=0.756 val_acc=0.642
# Epoch 12 | loss=0.2337 | train_f1=0.714 val_f1=0.518 val_acc=0.494
# Epoch 13 | loss=0.2321 | train_f1=0.841 val_f1=0.616 val_acc=0.539
# Epoch 14 | loss=0.2273 | train_f1=0.928 val_f1=0.791 val_acc=0.667
# Epoch 15 | loss=0.2434 | train_f1=0.869 val_f1=0.695 val_acc=0.617
# Epoch 16 | loss=0.2083 | train_f1=0.943 val_f1=0.739 val_acc=0.621
# Epoch 17 | loss=0.1805 | train_f1=0.884 val_f1=0.647 val_acc=0.560
# Epoch 18 | loss=0.1544 | train_f1=0.896 val_f1=0.686 val_acc=0.588
# Epoch 19 | loss=0.1442 | train_f1=0.944 val_f1=0.721 val_acc=0.605
# Epoch 20 | loss=0.1422 | train_f1=0.946 val_f1=0.683 val_acc=0.576
# Saved best checkpoint to /content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max_prob-055.pt
# Test metrics | accuracy=0.594 precision=0.727 recall=0.680 f1=0.703
