# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas6028/x-coach/blob/main/notebooks/run_videomae_video_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier.pt" \
  --epochs 20
# Out:
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, positives: 812, negatives: 324
# Epoch 01 | loss=0.5431 | train_f1=0.755 val_f1=0.709 val_acc=0.609
# Epoch 02 | loss=0.3902 | train_f1=0.734 val_f1=0.627 val_acc=0.560
# Epoch 03 | loss=0.3557 | train_f1=0.739 val_f1=0.624 val_acc=0.568
# Epoch 04 | loss=0.3289 | train_f1=0.874 val_f1=0.786 val_acc=0.658
# Epoch 05 | loss=0.2999 | train_f1=0.881 val_f1=0.795 val_acc=0.679
# Epoch 06 | loss=0.2982 | train_f1=0.812 val_f1=0.686 val_acc=0.588
# Epoch 07 | loss=0.2896 | train_f1=0.882 val_f1=0.723 val_acc=0.605
# Epoch 08 | loss=0.2755 | train_f1=0.892 val_f1=0.755 val_acc=0.630
# Epoch 09 | loss=0.2592 | train_f1=0.888 val_f1=0.709 val_acc=0.609
# Epoch 10 | loss=0.2469 | train_f1=0.681 val_f1=0.516 val_acc=0.498
# Epoch 11 | loss=0.2604 | train_f1=0.916 val_f1=0.728 val_acc=0.609
# Epoch 12 | loss=0.2206 | train_f1=0.894 val_f1=0.737 val_acc=0.642
# Epoch 13 | loss=0.1973 | train_f1=0.921 val_f1=0.728 val_acc=0.621
# Epoch 14 | loss=0.1850 | train_f1=0.764 val_f1=0.573 val_acc=0.539
# Epoch 15 | loss=0.1907 | train_f1=0.903 val_f1=0.702 val_acc=0.605
# Epoch 16 | loss=0.1822 | train_f1=0.919 val_f1=0.722 val_acc=0.617
# Epoch 17 | loss=0.1753 | train_f1=0.938 val_f1=0.759 val_acc=0.654
# Epoch 18 | loss=0.1664 | train_f1=0.925 val_f1=0.696 val_acc=0.597
# Epoch 19 | loss=0.1557 | train_f1=0.939 val_f1=0.699 val_acc=0.597
# Epoch 20 | loss=0.1531 | train_f1=0.956 val_f1=0.756 val_acc=0.634
# Saved best checkpoint to /content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier.pt
# Test metrics | accuracy=0.635 precision=0.715 recall=0.802 f1=0.756
