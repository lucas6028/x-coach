# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas6028/x-coach/blob/main/notebooks/run_videomae_video_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max3.pt" \
  --epochs 20
# Out:
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, positives: 812, negatives: 324
# Epoch 01 | loss=0.5526 | train_f1=0.794 val_f1=0.718 val_acc=0.593
# Epoch 02 | loss=0.3832 | train_f1=0.793 val_f1=0.710 val_acc=0.601
# Epoch 03 | loss=0.3742 | train_f1=0.828 val_f1=0.730 val_acc=0.613
# Epoch 04 | loss=0.3575 | train_f1=0.699 val_f1=0.601 val_acc=0.519
# Epoch 05 | loss=0.3269 | train_f1=0.874 val_f1=0.765 val_acc=0.646
# Epoch 06 | loss=0.3097 | train_f1=0.776 val_f1=0.653 val_acc=0.572
# Epoch 07 | loss=0.3188 | train_f1=0.854 val_f1=0.726 val_acc=0.617
# Epoch 08 | loss=0.2928 | train_f1=0.872 val_f1=0.754 val_acc=0.638
# Epoch 09 | loss=0.3046 | train_f1=0.837 val_f1=0.658 val_acc=0.568
# Epoch 10 | loss=0.2588 | train_f1=0.894 val_f1=0.689 val_acc=0.580
# Epoch 11 | loss=0.2490 | train_f1=0.793 val_f1=0.579 val_acc=0.514
# Epoch 12 | loss=0.2478 | train_f1=0.919 val_f1=0.732 val_acc=0.609
# Epoch 13 | loss=0.2159 | train_f1=0.916 val_f1=0.720 val_acc=0.601
# Epoch 14 | loss=0.2128 | train_f1=0.937 val_f1=0.755 val_acc=0.642
# Epoch 15 | loss=0.1986 | train_f1=0.934 val_f1=0.677 val_acc=0.572
# Epoch 16 | loss=0.1663 | train_f1=0.920 val_f1=0.704 val_acc=0.593
# Epoch 17 | loss=0.1780 | train_f1=0.934 val_f1=0.741 val_acc=0.630
# Epoch 18 | loss=0.1652 | train_f1=0.942 val_f1=0.756 val_acc=0.626
# Epoch 19 | loss=0.1573 | train_f1=0.949 val_f1=0.716 val_acc=0.609
# Epoch 20 | loss=0.2032 | train_f1=0.953 val_f1=0.795 val_acc=0.671
# Saved best checkpoint to /content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max3.pt
# Test metrics | accuracy=0.701 precision=0.724 recall=0.930 f1=0.814
