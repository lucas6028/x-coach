# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas6028/x-coach/blob/main/notebooks/run_videomae_video_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max_bce-07.pt" \
  --epochs 20
# Out:
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, positives: 812, negatives: 324
# Epoch 01 | loss=0.5690 | train_f1=0.838 val_f1=0.782 val_acc=0.654
# Epoch 02 | loss=0.3480 | train_f1=0.450 val_f1=0.333 val_acc=0.391
# Epoch 03 | loss=0.3112 | train_f1=0.834 val_f1=0.711 val_acc=0.584
# Epoch 04 | loss=0.2793 | train_f1=0.490 val_f1=0.404 val_acc=0.453
# Epoch 05 | loss=0.2797 | train_f1=0.815 val_f1=0.663 val_acc=0.556
# Epoch 06 | loss=0.2764 | train_f1=0.535 val_f1=0.409 val_acc=0.453
# Epoch 07 | loss=0.2651 | train_f1=0.651 val_f1=0.478 val_acc=0.461
# Epoch 08 | loss=0.2444 | train_f1=0.884 val_f1=0.774 val_acc=0.658
# Epoch 09 | loss=0.2394 | train_f1=0.725 val_f1=0.535 val_acc=0.486
# Epoch 10 | loss=0.2240 | train_f1=0.821 val_f1=0.669 val_acc=0.560
# Epoch 11 | loss=0.2162 | train_f1=0.890 val_f1=0.753 val_acc=0.638
# Epoch 12 | loss=0.2078 | train_f1=0.854 val_f1=0.660 val_acc=0.564
# Epoch 13 | loss=0.1920 | train_f1=0.911 val_f1=0.730 val_acc=0.617
# Epoch 14 | loss=0.2043 | train_f1=0.914 val_f1=0.695 val_acc=0.584
# Epoch 15 | loss=0.1648 | train_f1=0.932 val_f1=0.789 val_acc=0.671
# Epoch 16 | loss=0.1906 | train_f1=0.801 val_f1=0.592 val_acc=0.523
# Epoch 17 | loss=0.1613 | train_f1=0.929 val_f1=0.789 val_acc=0.667
# Epoch 18 | loss=0.1495 | train_f1=0.854 val_f1=0.640 val_acc=0.556
# Epoch 19 | loss=0.1623 | train_f1=0.911 val_f1=0.679 val_acc=0.580
# Epoch 20 | loss=0.1350 | train_f1=0.803 val_f1=0.585 val_acc=0.514
# Saved best checkpoint to /content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max_bce-07.pt
# Test metrics | accuracy=0.557 precision=0.762 recall=0.541 f1=0.633
