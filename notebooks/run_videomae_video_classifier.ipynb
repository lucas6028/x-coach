# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier.pt" \
  --epochs 20 \
  --seed 42
# Out:
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, seed: 42
# Class balance | train positives=812 negatives=324 | val positives=165 negatives=78 | test positives=172 negatives=72
# Epoch 01 | loss=0.5223 | train_f1=0.827 val_f1=0.809 val_acc=0.679 val_threshold=0.080
# Epoch 02 | loss=0.4006 | train_f1=0.675 val_f1=0.810 val_acc=0.687 val_threshold=0.204
# Epoch 03 | loss=0.3699 | train_f1=0.343 val_f1=0.814 val_acc=0.691 val_threshold=0.089
# Epoch 04 | loss=0.3608 | train_f1=0.821 val_f1=0.810 val_acc=0.683 val_threshold=0.183
# Epoch 05 | loss=0.3361 | train_f1=0.868 val_f1=0.809 val_acc=0.679 val_threshold=0.100
# Epoch 06 | loss=0.3316 | train_f1=0.764 val_f1=0.811 val_acc=0.683 val_threshold=0.055
# Epoch 07 | loss=0.2982 | train_f1=0.767 val_f1=0.809 val_acc=0.679 val_threshold=0.025
# Epoch 08 | loss=0.2869 | train_f1=0.860 val_f1=0.809 val_acc=0.679 val_threshold=0.025
# Epoch 09 | loss=0.2829 | train_f1=0.528 val_f1=0.813 val_acc=0.687 val_threshold=0.010
# Epoch 10 | loss=0.2757 | train_f1=0.871 val_f1=0.810 val_acc=0.687 val_threshold=0.207
# Epoch 11 | loss=0.2488 | train_f1=0.911 val_f1=0.811 val_acc=0.683 val_threshold=0.051
# Epoch 12 | loss=0.2357 | train_f1=0.883 val_f1=0.813 val_acc=0.687 val_threshold=0.052
# Epoch 13 | loss=0.2152 | train_f1=0.852 val_f1=0.813 val_acc=0.687 val_threshold=0.032
# Epoch 14 | loss=0.2069 | train_f1=0.917 val_f1=0.810 val_acc=0.683 val_threshold=0.115
# Epoch 15 | loss=0.1942 | train_f1=0.931 val_f1=0.809 val_acc=0.679 val_threshold=0.007
# Epoch 16 | loss=0.1870 | train_f1=0.950 val_f1=0.809 val_acc=0.679 val_threshold=0.004
# Epoch 17 | loss=0.1829 | train_f1=0.913 val_f1=0.809 val_acc=0.679 val_threshold=0.031
# Epoch 18 | loss=0.1720 | train_f1=0.961 val_f1=0.809 val_acc=0.679 val_threshold=0.009
# Epoch 19 | loss=0.1582 | train_f1=0.939 val_f1=0.809 val_acc=0.679 val_threshold=0.000
# Epoch 20 | loss=0.1507 | train_f1=0.962 val_f1=0.809 val_acc=0.679 val_threshold=0.001
# Saved best checkpoint to /content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier.pt
# Train metrics | threshold=0.089 accuracy=0.740 precision=0.736 recall=0.993 f1=0.845 tp=806 fp=289 tn=35 fn=6
# Val metrics | threshold=0.089 accuracy=0.691 precision=0.689 recall=0.994 f1=0.814 tp=164 fp=74 tn=4 fn=1
# Test metrics | threshold=0.089 accuracy=0.709 precision=0.711 recall=0.988 f1=0.827 tp=170 fp=69 tn=3 fn=2
