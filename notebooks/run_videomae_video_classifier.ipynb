# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas6028/x-coach/blob/main/notebooks/run_videomae_video_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. 掛載 Google Drive 並準備檔案

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. 安裝必要的套件

# %% [markdown]
# ### 3. 執行腳本 (覆寫預設路徑)

# %%
# !python /content/drive/MyDrive/x-coach/src/videomae_video_classifier.py \
  --feature-dir "/content/drive/MyDrive/x-coach/data/videomae_feature_extraction" \
  --train-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/train_keys.json" \
  --test-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/test_keys.json" \
  --val-keys "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Splits/val_keys.json" \
  --forward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_forward.json" \
  --inward-labels "/content/drive/MyDrive/x-coach/data/Fitness-AQA_dataset_release/Squat/Labeled_Dataset/Labels/error_knees_inward.json" \
  --output-path "/content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max_prob-0.6.pt" \
  --epochs 20
# Out:
# Training on 1136 train / 243 val / 244 test samples.
# Feature dim: 768, positives: 812, negatives: 324
# Epoch 01 | loss=0.6583 | train_f1=0.228 val_f1=0.251 val_acc=0.412
# Epoch 02 | loss=0.3905 | train_f1=0.845 val_f1=0.761 val_acc=0.630
# Epoch 03 | loss=0.3730 | train_f1=0.615 val_f1=0.504 val_acc=0.490
# Epoch 04 | loss=0.3533 | train_f1=0.771 val_f1=0.614 val_acc=0.535
# Epoch 05 | loss=0.3393 | train_f1=0.539 val_f1=0.427 val_acc=0.469
# Epoch 06 | loss=0.3162 | train_f1=0.647 val_f1=0.480 val_acc=0.457
# Epoch 07 | loss=0.3030 | train_f1=0.638 val_f1=0.455 val_acc=0.457
# Epoch 08 | loss=0.2959 | train_f1=0.628 val_f1=0.458 val_acc=0.465
# Epoch 09 | loss=0.2808 | train_f1=0.612 val_f1=0.435 val_acc=0.465
# Epoch 10 | loss=0.2654 | train_f1=0.797 val_f1=0.586 val_acc=0.523
# Epoch 11 | loss=0.2487 | train_f1=0.829 val_f1=0.609 val_acc=0.535
# Epoch 12 | loss=0.2478 | train_f1=0.863 val_f1=0.616 val_acc=0.523
# Epoch 13 | loss=0.2358 | train_f1=0.807 val_f1=0.584 val_acc=0.519
# Epoch 14 | loss=0.2315 | train_f1=0.839 val_f1=0.587 val_acc=0.514
# Epoch 15 | loss=0.2114 | train_f1=0.808 val_f1=0.605 val_acc=0.543
# Epoch 16 | loss=0.1890 | train_f1=0.937 val_f1=0.714 val_acc=0.605
# Epoch 17 | loss=0.1887 | train_f1=0.940 val_f1=0.736 val_acc=0.626
# Epoch 18 | loss=0.1768 | train_f1=0.953 val_f1=0.773 val_acc=0.654
# Epoch 19 | loss=0.1769 | train_f1=0.934 val_f1=0.702 val_acc=0.601
# Epoch 20 | loss=0.1516 | train_f1=0.710 val_f1=0.555 val_acc=0.531
# Saved best checkpoint to /content/drive/MyDrive/x-coach/data/videomae_feature_classifier/checkpoints/videomae_classifier_max_prob-0.6.pt
# Test metrics | accuracy=0.504 precision=0.768 recall=0.424 f1=0.547
